# %% [markdown]
# # Machine Learning Unsupervised
#
# ##  t-SNE manifold learning algorithm
#
# __Goal:__
# The purpose of this notebook is to learn how to use an unsupervised learning algorithm, **t-SNE** using sklearn.
#
# __At the end of this notebook you will be able to:__
# > 1. Run a t-SNE algorithm.
# > 2. Understand how you can configure the algorithm.
# > 3. Know the advantages and disadvantages of the algorithm.
#
# ## Introduction
# t-SNE [1] is a tool to visualize high-dimensional data. It converts
# similarities between data points to joint probabilities and tries
# to minimize the Kullback-Leibler divergence between the joint
# probabilities of the low-dimensional embedding and the
# high-dimensional data. t-SNE has a cost function that is not convex,
# i.e. with different initializations we can get different results.
#
# [1] van der Maaten, L.J.P.; Hinton, G.E. Visualizing High-Dimensional Data
#     Using t-SNE. Journal of Machine Learning Research 9:2579-2605, 2008.
#     Use Case for t-SNE
#
# ## Use case
# t-SNE could be used on high-dimensional data and then the output of those dimensions then become inputs to some other classification model. t-SNE could be used for data exploration, to learn more about segments. t-SNE often show clear separation in the data. This can be used to select a cluster number or evaluating relations. t-SNE however is not a clustering approach since it does not preserve the inputs like PCA and the values may often change between runs so it’s purely for exploration [2]
#
# https://towardsdatascience.com/an-introduction-to-t-sne-with-python-example-5a3a293108d1

# %%
# libraries
import pandas as pd
import numpy as np
from sklearn.manifold import TSNE
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def plot_data(X, df):
    #add x, y features to the original df
    df['HCC'] = X[:,0]
    df['normal'] = X[:,1]
    sns.scatterplot(x = 'HCC', y = 'normal', hue ='type', data = df, alpha = 0.5, palette=['red','blue'])
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    plt.show()

# %% [markdown]
# ## the data
# The data used is liver data that contains gene expression data of healthy donor liver as well as tumor and paired non-tumor tissue of HCC patients.
#
# CSV file containing the gene expression levels of 22277 genes (columns) from 357 samples (rows). There are 2 different types represented in this dataset (column "type"). More information about this dataset, as well as other file formats such as TAB and ARFF, data visualization, and classification and clustering benchmarks are freely available at the official CuMiDa website http://sbcb.inf.ufrgs.br/cumida

# %% [markdown]
# # Preprocessing the data
#
# First we will load the data and check for missing data and distributions. Then we will prepare the feauture matrix X

# %%
df = pd.read_csv('../Data/Liver_GSE14520_U133A.csv')

# %%
df.shape
# Out:
# (357, 22279)

# %%
df.head()
# Out:
#             samples type  1007_s_at   1053_at    117_at    121_at  1255_g_at  \
# 0  GSM362958.CEL.gz  HCC   6.801198  4.553189  6.787790  5.430893   3.250222
# 1  GSM362959.CEL.gz  HCC   7.585956  4.193540  3.763183  6.003593   3.309387
# 2  GSM362960.CEL.gz  HCC   7.803370  4.134075  3.433113  5.395057   3.476944
# 3  GSM362964.CEL.gz  HCC   6.920840  4.000651  3.754500  5.645297   3.387530
# 4  GSM362965.CEL.gz  HCC   6.556480  4.599010  4.066155  6.344537   3.372081
#
#     1294_at   1316_at   1320_at  ...  AFFX-r2-Ec-bioD-3_at  \
# 0  6.272688  3.413405  3.374910  ...             10.735084
# 1  6.291927  3.754777  3.587603  ...             11.528447
# 2  5.825713  3.505036  3.687333  ...             10.892460
# 3  6.470458  3.629249  3.577534  ...             10.686871
# 4  5.439280  3.762213  3.440714  ...             11.014454
#
#    AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# 0             10.398843            12.298551            12.270505
# 1             11.369919            12.867048            12.560433
# 2             10.416151            12.356337            11.888482
# 3             10.524836            12.006596            11.846195
# 4             10.775566            12.657182            12.573076
#
#    AFFX-ThrX-3_at  AFFX-ThrX-5_at  AFFX-ThrX-M_at  AFFX-TrpnX-3_at  \
# 0        3.855588        3.148321        3.366087         3.199008
# 1        4.016561        3.282867        3.541994         3.548680
# 2        3.839367        3.598851        3.516791         3.484089
# 3        3.867602        3.180472        3.309547         3.425501
# 4        4.091440        3.306729        3.493704         3.205771
#
#    AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# 0         3.160388         3.366417
# 1         3.460083         3.423348
# 2         3.282626         3.512024
# 3         3.166613         3.377499
# 4         3.378567         3.392938
#
# [5 rows x 22279 columns]

# %%
set(df.type)
# Out:
# {'HCC', 'normal'}

# %%
len(df)
# Out:
# 357

# %%
df['type'].value_counts()
# Out:
# HCC       181
# normal    176
# Name: type, dtype: int64

# %%
df.head()
# Out:
#             samples type  1007_s_at   1053_at    117_at    121_at  1255_g_at  \
# 0  GSM362958.CEL.gz  HCC   6.801198  4.553189  6.787790  5.430893   3.250222
# 1  GSM362959.CEL.gz  HCC   7.585956  4.193540  3.763183  6.003593   3.309387
# 2  GSM362960.CEL.gz  HCC   7.803370  4.134075  3.433113  5.395057   3.476944
# 3  GSM362964.CEL.gz  HCC   6.920840  4.000651  3.754500  5.645297   3.387530
# 4  GSM362965.CEL.gz  HCC   6.556480  4.599010  4.066155  6.344537   3.372081
#
#     1294_at   1316_at   1320_at  ...  AFFX-r2-Ec-bioD-3_at  \
# 0  6.272688  3.413405  3.374910  ...             10.735084
# 1  6.291927  3.754777  3.587603  ...             11.528447
# 2  5.825713  3.505036  3.687333  ...             10.892460
# 3  6.470458  3.629249  3.577534  ...             10.686871
# 4  5.439280  3.762213  3.440714  ...             11.014454
#
#    AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# 0             10.398843            12.298551            12.270505
# 1             11.369919            12.867048            12.560433
# 2             10.416151            12.356337            11.888482
# 3             10.524836            12.006596            11.846195
# 4             10.775566            12.657182            12.573076
#
#    AFFX-ThrX-3_at  AFFX-ThrX-5_at  AFFX-ThrX-M_at  AFFX-TrpnX-3_at  \
# 0        3.855588        3.148321        3.366087         3.199008
# 1        4.016561        3.282867        3.541994         3.548680
# 2        3.839367        3.598851        3.516791         3.484089
# 3        3.867602        3.180472        3.309547         3.425501
# 4        4.091440        3.306729        3.493704         3.205771
#
#    AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# 0         3.160388         3.366417
# 1         3.460083         3.423348
# 2         3.282626         3.512024
# 3         3.166613         3.377499
# 4         3.378567         3.392938
#
# [5 rows x 22279 columns]

# %%
df = df.set_index('samples')

# %%
data = df.select_dtypes(include=np.number)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 357 entries, GSM362958.CEL.gz to GSM712541.CEL.gz
# Columns: 22277 entries, 1007_s_at to AFFX-TrpnX-M_at
# dtypes: float64(22277)
# memory usage: 60.7+ MB

# %%
data.head()
# Out:
#                   1007_s_at   1053_at    117_at    121_at  1255_g_at  \
# samples
# GSM362958.CEL.gz   6.801198  4.553189  6.787790  5.430893   3.250222
# GSM362959.CEL.gz   7.585956  4.193540  3.763183  6.003593   3.309387
# GSM362960.CEL.gz   7.803370  4.134075  3.433113  5.395057   3.476944
# GSM362964.CEL.gz   6.920840  4.000651  3.754500  5.645297   3.387530
# GSM362965.CEL.gz   6.556480  4.599010  4.066155  6.344537   3.372081
#
#                    1294_at   1316_at   1320_at  1405_i_at    1431_at  ...  \
# samples                                                               ...
# GSM362958.CEL.gz  6.272688  3.413405  3.374910   3.654116   3.804983  ...
# GSM362959.CEL.gz  6.291927  3.754777  3.587603   5.137159   8.622475  ...
# GSM362960.CEL.gz  5.825713  3.505036  3.687333   4.515175  12.681439  ...
# GSM362964.CEL.gz  6.470458  3.629249  3.577534   5.192624  11.759412  ...
# GSM362965.CEL.gz  5.439280  3.762213  3.440714   4.961625  10.318552  ...
#
#                   AFFX-r2-Ec-bioD-3_at  AFFX-r2-Ec-bioD-5_at  \
# samples
# GSM362958.CEL.gz             10.735084             10.398843
# GSM362959.CEL.gz             11.528447             11.369919
# GSM362960.CEL.gz             10.892460             10.416151
# GSM362964.CEL.gz             10.686871             10.524836
# GSM362965.CEL.gz             11.014454             10.775566
#
#                   AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  AFFX-ThrX-3_at  \
# samples
# GSM362958.CEL.gz            12.298551            12.270505        3.855588
# GSM362959.CEL.gz            12.867048            12.560433        4.016561
# GSM362960.CEL.gz            12.356337            11.888482        3.839367
# GSM362964.CEL.gz            12.006596            11.846195        3.867602
# GSM362965.CEL.gz            12.657182            12.573076        4.091440
#
#                   AFFX-ThrX-5_at  AFFX-ThrX-M_at  AFFX-TrpnX-3_at  \
# samples
# GSM362958.CEL.gz        3.148321        3.366087         3.199008
# GSM362959.CEL.gz        3.282867        3.541994         3.548680
# GSM362960.CEL.gz        3.598851        3.516791         3.484089
# GSM362964.CEL.gz        3.180472        3.309547         3.425501
# GSM362965.CEL.gz        3.306729        3.493704         3.205771
#
#                   AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# samples
# GSM362958.CEL.gz         3.160388         3.366417
# GSM362959.CEL.gz         3.460083         3.423348
# GSM362960.CEL.gz         3.282626         3.512024
# GSM362964.CEL.gz         3.166613         3.377499
# GSM362965.CEL.gz         3.378567         3.392938
#
# [5 rows x 22277 columns]

# %%
data.describe()
# Out:
#         1007_s_at     1053_at      117_at      121_at   1255_g_at     1294_at  \
# count  357.000000  357.000000  357.000000  357.000000  357.000000  357.000000
# mean     6.919697    4.364608    3.997815    5.676159    3.196624    5.944732
# std      0.795479    0.517078    0.458061    0.324140    0.117558    0.460469
# min      5.439881    3.208187    3.349685    4.843217    2.926611    4.408074
# 25%      6.458913    4.022586    3.756995    5.470514    3.113514    5.691971
# 50%      6.775267    4.246193    3.898834    5.663660    3.183908    6.013986
# 75%      7.141789    4.602921    4.125593    5.884673    3.269651    6.240367
# max     10.203681    7.118403    8.451671    6.421155    3.624480    7.321780
#
#           1316_at     1320_at   1405_i_at     1431_at  ...  \
# count  357.000000  357.000000  357.000000  357.000000  ...
# mean     3.784451    3.535687    5.116819   10.975748  ...
# std      0.223318    0.146379    1.056504    2.707422  ...
# min      3.213066    3.201922    3.093790    3.383942  ...
# 25%      3.650583    3.433129    4.387587   10.065293  ...
# 50%      3.767319    3.526540    4.993191   12.352463  ...
# 75%      3.905954    3.606105    5.772551   12.796926  ...
# max      4.616552    4.123240    8.876519   13.342468  ...
#
#        AFFX-r2-Ec-bioD-3_at  AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  \
# count            357.000000            357.000000           357.000000
# mean              11.877943             11.655396            13.102149
# std                0.685135              0.704137             0.391878
# min                8.974751              8.994940            11.490197
# 25%               11.490295             11.276094            12.901514
# 50%               11.925433             11.728519            13.161884
# 75%               12.352193             12.120636            13.352289
# max               13.232389             13.167538            13.880141
#
#        AFFX-r2-P1-cre-5_at  AFFX-ThrX-3_at  AFFX-ThrX-5_at  AFFX-ThrX-M_at  \
# count           357.000000      357.000000      357.000000      357.000000
# mean             12.969547        5.100523        3.625519        4.027291
# std               0.458324        1.340726        0.618638        0.891140
# min              10.867025        3.393593        2.987330        3.052818
# 25%              12.733371        3.953988        3.258797        3.426692
# 50%              13.023215        4.688599        3.413292        3.679792
# 75%              13.248107        6.047752        3.807439        4.318741
# max              13.938760        9.643160        7.774825        8.461628
#
#        AFFX-TrpnX-3_at  AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# count       357.000000       357.000000       357.000000
# mean          3.230486         3.202475         3.280976
# std           0.166570         0.114835         0.153893
# min           2.928648         2.975488         2.973336
# 25%           3.131927         3.127833         3.177872
# 50%           3.194545         3.187260         3.243091
# 75%           3.284613         3.265791         3.341924
# max           4.097030         3.763071         3.969724
#
# [8 rows x 22277 columns]

# %% [markdown]
# data ranges differ, needs to be scaled

# %%
#check for missing data
missing = data.isnull().sum()
missing[missing > 0]
# Out:
# Series([], dtype: int64)

# %%
#perform log transformation on skewed_columns
skew_columns = (data.skew().sort_values(ascending = False))
skew_columns = skew_columns[skew_columns > 0.75]
for col in skew_columns.index.tolist():
   data[col] = np.log1p(data[col])

# %%
#normalize
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(data)

# %% [markdown]
# # visualization with t-SNE

# %%
#initiate instance
X_embedded = TSNE(n_components=2, learning_rate='auto',
                   init='random', random_state = 42)
#fit 
X_embedded = X_embedded.fit_transform(X)
# produced an two dimension array with x,y features for every row, since n_components = 2
X_embedded.shape
# Out:
# (357, 2)

# %%
plot_data(X_embedded,df)

# %% [markdown]
# It is highly recommended to use another dimensionality reduction
# method (e.g. PCA for dense data or TruncatedSVD for sparse data)
# to reduce the number of dimensions to a reasonable amount (e.g. 50)
# if the number of features is very high. This will suppress some
# noise and speed up the computation of pairwise distances between
# samples. For more tips see Laurens van der Maaten's FAQ [2]
#
# [2] van der Maaten, L.J.P. t-Distributed Stochastic Neighbor Embedding
#     https://lvdmaaten.github.io/tsne/

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=50)
pc = pca.fit_transform(X)

# %%
#initiate instance
X_embedded = TSNE(n_components=2, learning_rate='auto', random_state = 42, init='random')
#fit 
X_embedded = X_embedded.fit_transform(pc)
# produced an two dimension array with x,y features for every row, since n_components = 2
X_embedded.shape
# Out:
# (357, 2)

# %%
#X_embedded

# %%
plot_data(X_embedded,df)

# %% [markdown]
# ## Hypertuning the parameter

# %%
#https://towardsdatascience.com/hyperparameter-tuning-in-python-21a76794a1f7
from sklearn.manifold import TSNE
from sklearn.model_selection import GridSearchCV
#Create an instance of the t-SNE algorithm
tsne = TSNE()
#specifies the range of values to explore during the hyperparameter tuning process
param_grid = {
    'perplexity': [5, 8, 10, 13, 16, 19, 25, 35, 50],
    'learning_rate': [100, 200, 500],
    'n_iter': [1000, 2000, 5000]
}
grid_search = GridSearchCV(tsne, param_grid,scoring='accuracy', cv=5,refit=True)
grid_search.fit(X)  # X represents the input data
# Out:
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# ...
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 759, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# GridSearchCV(cv=5, estimator=TSNE(),
#              param_grid={'learning_rate': [100, 200, 500],
#                          'n_iter': [1000, 2000, 5000],
#                          'perplexity': [5, 8, 10, 13, 16, 19, 25, 35, 50]},
#              scoring='accuracy')

# %%
# the best parameters and best fit the foloowing functions can be implimented
best_params = grid_search.best_params_
tsne = TSNE(**best_params)
X_embedded = tsne.fit_transform(X)
plot_data(X_embedded,df)
# Out:
# C:\Users\alanp\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %% [markdown]
# ## `perplexity`
# Perplexity is a critical hyperparameter of tSNE. The author of tSNE, Laurens van der Maaten, mentions that typical values for the perplexity range between 5 and 50 (default 30). The perplexity is related to the number of nearest neighbors that is used in other manifold learning algorithms. Larger datasets usually require a larger perplexity. A Rule of thumb is to use $N^{\frac{1}{2}}$

# %%
len(df)**(1/2)
# Out:
# 18.894443627691185

# %%
#perplexity is around 19, will run on both pca and X transform data

# %%
def plot_sub(X, df):
    df['comp1'] = X[:,0]
    df['comp2'] = X[:,1]
    ax = sns.scatterplot(x = 'comp1', y = 'comp2', hue = 'type', data = df, 
                         legend = False, alpha = 0.5, palette=['red', 'blue'])
    return ax

p = [5, 8, 10, 13, 16, 19, 25, 35, 50]
fig = plt.figure(figsize=(12, 8))
plt.subplots_adjust(wspace=0.7, hspace=0.7)
for i in range(9):
    ax = fig.add_subplot(3, 3, i+1)
    X_embedded = TSNE(n_components=2, learning_rate='auto', init='random', perplexity = p[i], random_state = 42)
    X_embedded = X_embedded.fit_transform(pc)
    plot_sub(X_embedded, df)
    ax.set_title(f'perplexity={p[i]}')
plt.show()

# %%
p = [5, 8, 10, 13, 16, 19, 25, 35, 50]
fig = plt.figure(figsize=(12, 8))
plt.subplots_adjust(wspace=0.7, hspace=0.7)
for i in range(9):
    ax = fig.add_subplot(3, 3, i+1)
    X_embedded = TSNE(n_components=2, learning_rate='auto', init='random', perplexity = p[i], random_state = 42)
    X_embedded = X_embedded.fit_transform(X)
    plot_sub(X_embedded, df)
    ax.set_title(f'perplexity={p[i]}')
plt.show()

# %% [markdown]
# It seems that the perplexity of 19 gives the most clear seperation

# %% [markdown]
# ## `method`
#
#     method = 'barnes_hut'
# is usely used in case of high number of observations. In our case we could use
#
#     method = 'exact'
# However this will increase computation time (algorithm in O(N^2) time) more itterations, the slower it will be.

# %%
#initiate instance
X_embedded = TSNE(n_components=2, 
                  learning_rate='auto', 
                  perplexity = 19, 
                  method='exact', 
                  random_state = 42, 
                  init='random')
#fit 
X_embedded = X_embedded.fit_transform(pc)
# produced an two dimension array with x,y features for every row, since n_components = 2
X_embedded.shape
# Out:
# (357, 2)

# %%
plot_data(X_embedded,df)

# %% [markdown]
# ## `n_iter`
# We learned that the number of itterations is of importance since in the t-distribution step it changes towards the optimal situation step by step. It should be at least 250. The more itterations, the more time however

# %%
p = [250, 260, 270, 300, 400, 500, 800, 1000, 2000]
fig = plt.figure(figsize=(12, 8))
plt.subplots_adjust(wspace=0.7, hspace=0.7)
for i in range(9):
    ax = fig.add_subplot(3, 3, i+1)
    X_embedded = TSNE(n_components=2, learning_rate='auto', init='random', 
                      perplexity = 19, 
                      random_state = 42, 
                      method = 'exact',
                      n_iter = p[i])
    X_embedded = X_embedded.fit_transform(pc)
    plot_sub(X_embedded, df)
    ax.set_title(f'n_iter={p[i]}')
plt.show()

# %% [markdown]
# Conclusion: there might be predicting value in the genes. We can see two almost seperated clusters the HCC and Normal, however, there are still overlapping colors. The visualization in two components x and y might nog capture all variation.

# %% [markdown]
# # Exercise

# %% [markdown]
# Compare for the file Brain_GSE50161.csv the pca versus the tSNE, to be found at http://sbcb.inf.ufrgs.br/cumida

# %%
df1 = pd.read_csv('../Data/Brain_GSE50161.csv')

# %%
df1.shape
# Out:
# (130, 54677)

# %%
df1.head()
# Out:
#    samples        type  1007_s_at   1053_at     117_at    121_at  1255_g_at  \
# 0      834  ependymoma  12.498150  7.604868   6.880934  9.027128   4.176175
# 1      835  ependymoma  13.067436  7.998090   7.209076  9.723322   4.826126
# 2      836  ependymoma  13.068179  8.573674   8.647684  9.613002   4.396581
# 3      837  ependymoma  12.456040  9.098977   6.628784  8.517677   4.154847
# 4      838  ependymoma  12.699958  8.800721  11.556188  9.166309   4.165891
#
#     1294_at   1316_at   1320_at  ...  AFFX-r2-Ec-bioD-3_at  \
# 0  7.224920  6.085942  6.835999  ...              9.979005
# 1  7.539381  6.250962  8.012549  ...             11.924749
# 2  7.813101  6.007746  7.178156  ...             12.154405
# 3  8.361843  6.596064  6.347285  ...             11.969072
# 4  7.923826  6.212754  6.866387  ...             11.411701
#
#    AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# 0              9.926470            12.719785            12.777792
# 1             11.215930            13.605662            13.401342
# 2             11.532460            13.764593            13.477800
# 3             11.288801            13.600828            13.379029
# 4             11.169317            13.751442            13.803646
#
#    AFFX-ThrX-3_at  AFFX-ThrX-5_at  AFFX-ThrX-M_at  AFFX-TrpnX-3_at  \
# 0        5.403657        4.870548        4.047380         3.721936
# 1        5.224555        4.895315        3.786437         3.564481
# 2        5.303565        5.052184        4.005343         3.595382
# 3        4.953429        4.708371        3.892318         3.759429
# 4        4.892677        4.773806        3.796856         3.577544
#
#    AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# 0         4.516434         4.749940
# 1         4.430891         4.491416
# 2         4.563494         4.668827
# 3         4.748381         4.521275
# 4         4.504385         4.541450
#
# [5 rows x 54677 columns]

# %%
set(df1.type)
# Out:
# {'ependymoma',
#  'glioblastoma',
#  'medulloblastoma',
#  'normal',
#  'pilocytic_astrocytoma'}

# %% [markdown]
# For the brain data there are 5 different type value

# %%
df1['type'].value_counts()
# Out:
# ependymoma               46
# glioblastoma             34
# medulloblastoma          22
# pilocytic_astrocytoma    15
# normal                   13
# Name: type, dtype: int64

# %%
df1 = df1.set_index('samples')
# Out:
#                           type  1007_s_at   1053_at     117_at    121_at  \
# samples
# 834                 ependymoma  12.498150  7.604868   6.880934  9.027128
# 835                 ependymoma  13.067436  7.998090   7.209076  9.723322
# 836                 ependymoma  13.068179  8.573674   8.647684  9.613002
# 837                 ependymoma  12.456040  9.098977   6.628784  8.517677
# 838                 ependymoma  12.699958  8.800721  11.556188  9.166309
# ...                        ...        ...       ...        ...       ...
# 959      pilocytic_astrocytoma  12.658228  8.843270   7.672655  9.125912
# 960      pilocytic_astrocytoma  12.812823  8.510550   8.729699  9.104402
# 961      pilocytic_astrocytoma  12.706991  8.795721   7.772359  8.327273
# 962      pilocytic_astrocytoma  12.684593  8.293938   7.228186  8.494428
# 963      pilocytic_astrocytoma  12.397722  8.843524   8.825100  8.551541
#
#          1255_g_at   1294_at   1316_at   1320_at  1405_i_at  ...  \
# samples                                                      ...
# 834       4.176175  7.224920  6.085942  6.835999   5.898355  ...
# 835       4.826126  7.539381  6.250962  8.012549   5.453147  ...
# 836       4.396581  7.813101  6.007746  7.178156   8.400266  ...
# 837       4.154847  8.361843  6.596064  6.347285   4.900380  ...
# 838       4.165891  7.923826  6.212754  6.866387   5.405628  ...
# ...            ...       ...       ...       ...        ...  ...
# 959       5.495477  8.603892  7.747514  5.828978   6.926720  ...
# 960       3.967228  7.719089  7.092496  6.504812   6.157163  ...
# 961       6.329383  8.550471  6.613332  6.308945   7.494852  ...
# 962       6.049414  8.214729  7.287758  5.732710   6.296021  ...
# 963       5.002072  8.547894  6.920827  5.738159   6.383309  ...
#
#          AFFX-r2-Ec-bioD-3_at  AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  \
# samples
# 834                  9.979005              9.926470            12.719785
# 835                 11.924749             11.215930            13.605662
# 836                 12.154405             11.532460            13.764593
# 837                 11.969072             11.288801            13.600828
# 838                 11.411701             11.169317            13.751442
# ...                       ...                   ...                  ...
# 959                 13.170441             12.676080            14.124837
# 960                 13.040267             12.403316            13.978009
# 961                 12.825383             12.439265            14.328373
# 962                 13.116581             12.657967            14.390346
# 963                 13.117180             12.699932            14.286779
#
#          AFFX-r2-P1-cre-5_at  AFFX-ThrX-3_at  AFFX-ThrX-5_at  AFFX-ThrX-M_at  \
# samples
# 834                12.777792        5.403657        4.870548        4.047380
# 835                13.401342        5.224555        4.895315        3.786437
# 836                13.477800        5.303565        5.052184        4.005343
# 837                13.379029        4.953429        4.708371        3.892318
# 838                13.803646        4.892677        4.773806        3.796856
# ...                      ...             ...             ...             ...
# 959                13.996436        4.913579        4.399176        3.878855
# 960                13.812916        5.189600        4.912618        3.764800
# 961                14.008693        4.931460        4.712895        3.913637
# 962                14.194904        4.871092        4.739400        3.782980
# 963                14.088950        4.932377        4.700205        3.952850
#
#          AFFX-TrpnX-3_at  AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# samples
# 834             3.721936         4.516434         4.749940
# 835             3.564481         4.430891         4.491416
# 836             3.595382         4.563494         4.668827
# 837             3.759429         4.748381         4.521275
# 838             3.577544         4.504385         4.541450
# ...                  ...              ...              ...
# 959             3.680103         4.726784         4.564637
# 960             3.664920         4.628355         4.761351
# 961             3.700964         4.764693         4.834952
# 962             3.920363         4.665584         4.613326
# 963             3.678112         5.018501         4.704779
#
# [130 rows x 54676 columns]

# %%
data1 = df1.select_dtypes(include=np.number)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130 entries, 834 to 963
# Columns: 54675 entries, 1007_s_at to AFFX-TrpnX-M_at
# dtypes: float64(54675)
# memory usage: 54.2 MB

# %%
data1.head()
# Out:
#          1007_s_at   1053_at     117_at    121_at  1255_g_at   1294_at  \
# samples
# 834      12.498150  7.604868   6.880934  9.027128   4.176175  7.224920
# 835      13.067436  7.998090   7.209076  9.723322   4.826126  7.539381
# 836      13.068179  8.573674   8.647684  9.613002   4.396581  7.813101
# 837      12.456040  9.098977   6.628784  8.517677   4.154847  8.361843
# 838      12.699958  8.800721  11.556188  9.166309   4.165891  7.923826
#
#           1316_at   1320_at  1405_i_at   1431_at  ...  AFFX-r2-Ec-bioD-3_at  \
# samples                                           ...
# 834      6.085942  6.835999   5.898355  5.513410  ...              9.979005
# 835      6.250962  8.012549   5.453147  6.173106  ...             11.924749
# 836      6.007746  7.178156   8.400266  6.323471  ...             12.154405
# 837      6.596064  6.347285   4.900380  6.008684  ...             11.969072
# 838      6.212754  6.866387   5.405628  5.279579  ...             11.411701
#
#          AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# samples
# 834                  9.926470            12.719785            12.777792
# 835                 11.215930            13.605662            13.401342
# 836                 11.532460            13.764593            13.477800
# 837                 11.288801            13.600828            13.379029
# 838                 11.169317            13.751442            13.803646
#
#          AFFX-ThrX-3_at  AFFX-ThrX-5_at  AFFX-ThrX-M_at  AFFX-TrpnX-3_at  \
# samples
# 834            5.403657        4.870548        4.047380         3.721936
# 835            5.224555        4.895315        3.786437         3.564481
# 836            5.303565        5.052184        4.005343         3.595382
# 837            4.953429        4.708371        3.892318         3.759429
# 838            4.892677        4.773806        3.796856         3.577544
#
#          AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# samples
# 834             4.516434         4.749940
# 835             4.430891         4.491416
# 836             4.563494         4.668827
# 837             4.748381         4.521275
# 838             4.504385         4.541450
#
# [5 rows x 54675 columns]

# %%
data1.describe()
# Out:
#         1007_s_at     1053_at      117_at      121_at   1255_g_at     1294_at  \
# count  130.000000  130.000000  130.000000  130.000000  130.000000  130.000000
# mean    12.276393    8.769583    7.722634    9.160209    4.842069    7.968388
# std      0.790160    0.673396    1.037339    0.615369    0.922003    0.630260
# min     10.156207    6.627878    6.222515    8.044421    3.682762    6.560920
# 25%     11.679721    8.378760    7.007678    8.595505    4.207043    7.533713
# 50%     12.502518    8.786242    7.521674    9.194487    4.462729    7.915062
# 75%     12.883374    9.211098    8.249157    9.707397    5.276685    8.385912
# max     13.655639   10.716003   12.054143   10.407136    7.404503   10.164655
#
#           1316_at     1320_at   1405_i_at     1431_at  ...  \
# count  130.000000  130.000000  130.000000  130.000000  ...
# mean     6.800111    6.472452    6.068968    5.548389  ...
# std      0.537431    0.659847    0.904152    0.627754  ...
# min      5.910571    5.515079    4.491771    4.572279  ...
# 25%      6.389605    5.935051    5.462356    5.168066  ...
# 50%      6.654785    6.401447    5.856087    5.331755  ...
# 75%      7.143818    6.985782    6.476124    5.740363  ...
# max      8.110006    8.812959    8.646862    7.607336  ...
#
#        AFFX-r2-Ec-bioD-3_at  AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  \
# count            130.000000            130.000000           130.000000
# mean              12.371075             11.812911            13.793913
# std                0.609813              0.618190             0.320124
# min                9.979005              9.926470            12.719785
# 25%               12.056825             11.359850            13.605871
# 50%               12.415320             11.768853            13.774338
# 75%               12.757924             12.230375            13.969533
# max               13.480002             13.022222            14.476079
#
#        AFFX-r2-P1-cre-5_at  AFFX-ThrX-3_at  AFFX-ThrX-5_at  AFFX-ThrX-M_at  \
# count           130.000000      130.000000      130.000000      130.000000
# mean             13.619041        5.206208        4.811666        3.916795
# std               0.309078        0.220767        0.219851        0.165917
# min              12.777792        4.680072        4.247758        3.530287
# 25%              13.392790        5.031176        4.684169        3.807447
# 50%              13.614493        5.214618        4.785318        3.912025
# 75%              13.813191        5.324326        4.950025        4.009166
# max              14.273778        5.904952        5.619512        4.547821
#
#        AFFX-TrpnX-3_at  AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# count       130.000000       130.000000       130.000000
# mean          3.701539         4.627912         4.633377
# std           0.180251         0.160663         0.192353
# min           3.432622         4.278812         4.050006
# 25%           3.589381         4.530391         4.519694
# 50%           3.674620         4.607167         4.603287
# 75%           3.744824         4.718997         4.736634
# max           4.854368         5.420217         5.436919
#
# [8 rows x 54675 columns]

# %%
#check for missing data
missing = data1.isnull().sum()
missing[missing > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# since the data values differ, so needed to scale

# %%
#perform log transformation on skewed_columns
skew_columns = (data1.skew().sort_values(ascending = False))
skew_columns = skew_columns[skew_columns > 0.75]
for col in skew_columns.index.tolist():
   data1[col] = np.log1p(data1[col])

# %%
#normalize
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(data1)

# %%
#implementing another dimensionality reduction method (PCA)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=50)
pc = pca.fit_transform(X)

# %%
pc.shape
# Out:
# (130, 100)

# %% [markdown]
# ### visualization with t-SNE and PCA

# %%
X_embedded = TSNE(n_components=2, learning_rate='auto', random_state = 42, init='random')
#fit 
X_embedded = X_embedded.fit_transform(pc)
# produced an two dimension array with x,y features for every row, since n_components = 2
X_embedded.shape
# Out:
# (130, 2)

# %%
def plot_data(X, df):
    #add x, y features to the original df
    df['component1'] = X[:,0]
    df['component2'] = X[:,1]
    sns.scatterplot(x = 'component1', y = 'component2', hue ='type', data = df, alpha = 0.5, palette=['red','blue','green','black','yellow'])
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    plt.show()

# %%
plot_data(X_embedded,df1)

# %%
#initiate instance
X_embedded = TSNE(n_components=2, learning_rate='auto',
                   init='random', random_state = 42)
#fit 
X_embedded = X_embedded.fit_transform(X)
# produced an two dimension array with x,y features for every row, since n_components = 2
X_embedded.shape
# Out:
# (130, 2)

# %%
plot_data(X_embedded,df1)

# %% [markdown]
# ## Perplexity

# %%
len(df1)**(1/2)
# Out:
# 11.40175425099138

# %% [markdown]
# Perplexity range between 5 and 50 (default 30).In here perplexity is around 11

# %%
def plot_sub(X, df):
    #add x, y features to the original df
    df['comp1'] = X[:,0]
    df['comp2'] = X[:,1]
    ax = sns.scatterplot(x = 'comp1', y = 'comp2', hue = 'type', data = df, 
                         legend = False, alpha = 0.5, palette=['red', 'blue','green','black','yellow'])
    return ax
p = [5, 8, 10,11, 13, 16, 19, 25, 35, 50]
fig = plt.figure(figsize=(12, 8))
plt.subplots_adjust(wspace=0.7, hspace=0.7)
for i in range(9):
    ax = fig.add_subplot(3, 3, i+1)
    X_embedded = TSNE(n_components=2, learning_rate='auto', init='random', perplexity = p[i], random_state = 42)
    X_embedded = X_embedded.fit_transform(pc)
    plot_sub(X_embedded, df1)
    ax.set_title(f'perplexity={p[i]}')
plt.show()

# %%
p = [5, 8, 10,11, 13, 16, 19, 25, 35, 50]
fig = plt.figure(figsize=(12, 8))
plt.subplots_adjust(wspace=0.7, hspace=0.7)
for i in range(9):
    ax = fig.add_subplot(3, 3, i+1)
    X_embedded = TSNE(n_components=2, learning_rate='auto', init='random', perplexity = p[i], random_state = 42)
    X_embedded = X_embedded.fit_transform(X)
    plot_sub(X_embedded, df1)
    ax.set_title(f'perplexity={p[i]}')
plt.show()

# %% [markdown]
# It seems that the perplexity of 11 gives the most clear seperation for both PCA and t-SNE

# %%
#For the method we can use 'exact' since the number of observation is low
#initiate instance
X_embedded = TSNE(n_components=2, 
                  learning_rate='auto', 
                  perplexity = 11, 
                  method='exact', 
                  random_state = 42, 
                  init='random')
#fit 
X_embedded = X_embedded.fit_transform(pc)
# produced an two dimension array with x,y features for every row, since n_components = 2
X_embedded.shape
# Out:
# (130, 2)

# %%
plot_data(X_embedded,df1)

# %%
#initiate instance
X_embedded = TSNE(n_components=2, 
                  learning_rate='auto', 
                  perplexity = 11, 
                  method='exact', 
                  random_state = 42, 
                  init='random')
#fit 
X_embedded = X_embedded.fit_transform(X)
# produced an two dimension array with x,y features for every row, since n_components = 2
X_embedded.shape
# Out:
# (130, 2)

# %%
plot_data(X_embedded,df1)

# %% [markdown]
# From this above two plot for t-SNE and PCA. Almost all the cluster are seperated leading to a good visualization

# %%
p = [250, 260, 270, 300, 400, 500, 800, 1000, 2000]
fig = plt.figure(figsize=(12, 8))
plt.subplots_adjust(wspace=0.7, hspace=0.7)
for i in range(9):
    ax = fig.add_subplot(3, 3, i+1)
    X_embedded = TSNE(n_components=2, learning_rate='auto', init='random', 
                      perplexity = 11, 
                      random_state = 42, 
                      method = 'exact',
                      n_iter = p[i])
    X_embedded = X_embedded.fit_transform(pc)
    plot_sub(X_embedded, df1)
    ax.set_title(f'n_iter={p[i]}')
plt.show()

# %% [markdown]
# conclusion: For the brain data we can see almost five clusters. However, they might not be able to capture all complex structures of the data, leading to some degree of overlap between clusters(colors). It is possible that the dimensionality reduction performed by t-SNE or PCA is not sufficient to completely separate the clusters.
